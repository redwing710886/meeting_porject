# %%
#將各文本依出現次數排序合併後，取中位數
import codecs
import statistics

path = 'C:\\Users\\user\\Desktop\\課業相關\\碩士班\\SNA\\meeting\\情態動詞\\兩兩情態動詞整理\\output and conbine\\'
out_path = 'C:\\Users\\user\\Desktop\\'

file = {}
num = {}

with codecs.open(path+'new_conbine.txt','r','utf8') as f:
    content = f.readlines()
    
    check = ''
    
    for line in content:
        if line[0] == '#':
            file[line[1:].strip()] = []
            num[line[1:].strip()] = 0
            check = line[1:].strip()
        elif line[0] == '@':
            num[check] = int(line[1:])
        elif len(line.strip()) == 0:
            continue
        else:
            l = line.split()
            wc = l[0].split('_')
            #file[check].append([l[0][2:-2],l[1][1:-2],l[2]])
            if wc[0][0] != '該' and wc[1][0] != '會':
                file[check].append([wc[0],wc[1],l[1]])
        '''else:
            num[check] = int(line)'''
            
#with codecs.open(path+'a.csv','w','utf8') as f: 
#for i in file:
    #print (i)
    #for j in file[i]:
        #print (j[0],j[1],round(int(j[2])*1000000/num[i],2))
        #pass
        #f.write(j[0]+'_'+j[1]+','+str(round(int(j[2])*1000000/num[i],2))+'\r\n')

k = {} #數值
o = {} #名次數值

for i in file:
    #if i != 'diary':
    count = 1
    s = 1
    temp = 0
    for j in file[i]:
        if temp == round(int(j[2])*1000000/num[i],2):
            s = s - 1
        else:
            s = count
        if j[0]+'_'+j[1] in k:
            #k[j[0]+'_'+j[1]].append([i,round(int(j[2])*1000000/num[i],2)])
            k[j[0]+'_'+j[1]].append([i,s,round(int(j[2])*1000000/num[i],2)])
            o[j[0]+'_'+j[1]].append(s)
        else:
            #k[j[0]+'_'+j[1]] = [[i,round(int(j[2])*1000000/num[i],2)]]
            k[j[0]+'_'+j[1]] = [[i,s,round(int(j[2])*1000000/num[i],2)]]
            o[j[0]+'_'+j[1]] = [s]
        count = count + 1
        s = s + 1
        temp = round(int(j[2])*1000000/num[i],2)

#中位數
for i in o:
    o[i] = statistics.median(o[i])
                
o = sorted(o.items(), key=lambda d:d[1], reverse = False)

with codecs.open(out_path+'conbine_final.csv','w','utf8') as g:
    g.write('兩兩情態動詞'+','+'分數'+','+'FreeChina'+','+'SCS'+','+'diary'+','+'228'+'\r\n')
    lll = ['FreeChina','SCS','diary','228']
    for i in o:
        if len(k[i[0]]) == 0:
            continue
        print (i[0],i[1],k[i[0]])
        tt = i[0]+','+str(round(i[1],2))
        
        temp_dic = {}
        
        for j in k[i[0]]:
            #tt = tt + ',' + j[0] + '_' + str(j[1]) + '_' + str(j[2])
            temp_dic[j[0]] = j[1]
            
        for c in lll:
            if c not in temp_dic:
                tt = tt + ',' + '0'
            else:
                tt = tt + ',' + str(temp_dic[c])
        g.write(tt+'\r\n')
print ('END')
# Out:
# 要(D)_能(D) 1.0 [['SCS', 1, 621.0], ['diary', 1, 202.61], ['228', 2, 135.12], ['FreeChina', 1, 211.19]]
# 當(D)_可(D) 4.0 [['SCS', 29, 45.12], ['diary', 5, 49.12], ['228', 1, 258.98], ['FreeChina', 3, 99.71]]
# 應該(D)_要(D) 4 [['SCS', 4, 352.4], ['228', 3, 112.6], ['FreeChina', 32, 20.41]]
# 必須(D)_要(D) 4.5 [['SCS', 2, 489.21], ['diary', 7, 36.84], ['228', 20, 33.78], ['FreeChina', 2, 145.24]]
# 應(D)_可(D) 6.0 [['SCS', 6, 261.44], ['diary', 4, 55.26], ['228', 6, 78.82], ['FreeChina', 22, 29.05]]
# 要(D)_要(D) 6.0 [['SCS', 3, 437.64], ['diary', 8, 30.7], ['228', 7, 67.56], ['FreeChina', 5, 74.59]]
# 能(D)_能(D) 7.0 [['SCS', 5, 265.73], ['diary', 9, 24.56], ['228', 20, 33.78], ['FreeChina', 4, 92.64]]
# 必須(D)_能(D) 7.0 [['SCS', 8, 229.92], ['diary', 6, 42.98], ['228', 25, 22.52], ['FreeChina', 6, 72.23]]
# 可(D)_可(D) 8.5 [['SCS', 7, 245.68], ['diary', 9, 24.56], ['228', 25, 22.52], ['FreeChina', 8, 57.31]]
# 會(D)_要(D) 11 [['SCS', 11, 128.21], ['diary', 3, 61.4], ['FreeChina', 34, 18.84]]
# 可(D)_得(D) 11.0 [['SCS', 15, 85.24], ['diary', 27, 6.14], ['228', 7, 67.56], ['FreeChina', 7, 61.24]]
# 應(D)_應(D) 12.0 [['SCS', 40, 33.66], ['diary', 13, 18.42], ['228', 4, 101.34], ['FreeChina', 11, 53.39]]
# 要(D)_可以(D) 14.0 [['SCS', 12, 98.13], ['diary', 9, 24.56], ['228', 20, 33.78], ['FreeChina', 16, 34.54]]
# 應該(D)_可以(D) 16.5 [['SCS', 9, 181.21], ['diary', 19, 12.28], ['228', 36, 11.26], ['FreeChina', 14, 37.69]]
# 當(D)_能(D) 18 [['SCS', 67, 17.19], ['228', 4, 101.34], ['FreeChina', 18, 33.76]]
# 要(D)_可(D) 18.5 [['SCS', 21, 61.6], ['diary', 2, 73.68], ['228', 25, 22.52], ['FreeChina', 16, 34.54]]
# 可以(D)_可以(D) 19 [['SCS', 10, 169.75], ['diary', 19, 12.28], ['FreeChina', 19, 32.97]]
# 能(D)_要(D) 19 [['SCS', 19, 65.18], ['diary', 19, 12.28], ['FreeChina', 21, 29.83]]
# 須(D)_能(D) 19.5 [['SCS', 41, 32.95], ['diary', 27, 6.14], ['228', 11, 56.3], ['FreeChina', 12, 40.83]]
# 應(D)_能(D) 20.5 [['SCS', 14, 92.4], ['diary', 27, 6.14], ['228', 36, 11.26], ['FreeChina', 10, 54.96]]
# 會(D)_可(D) 20.5 [['SCS', 28, 47.99], ['diary', 13, 18.42], ['228', 7, 67.56], ['FreeChina', 61, 8.64]]
# 要(D)_必須(D) 21.0 [['SCS', 22, 58.02], ['diary', 19, 12.28], ['228', 36, 11.26], ['FreeChina', 20, 30.62]]
# 能(D)_可(D) 21.0 [['SCS', 17, 69.48], ['diary', 13, 18.42], ['228', 36, 11.26], ['FreeChina', 25, 26.69]]
# 得(D)_要(D) 21.5 [['SCS', 18, 66.61], ['diary', 27, 6.14], ['228', 25, 22.52], ['FreeChina', 13, 38.47]]
# 可(D)_能(D) 22 [['SCS', 25, 52.29], ['228', 20, 33.78], ['FreeChina', 22, 29.05]]
# 得(D)_能(D) 26 [['SCS', 26, 49.42], ['228', 15, 45.04], ['FreeChina', 36, 18.06]]
# 要(D)_能夠(D) 26.0 [['SCS', 13, 95.26], ['diary', 27, 6.14], ['228', 36, 11.26], ['FreeChina', 25, 26.69]]
# 應(D)_須(D) 27 [['diary', 27, 6.14], ['228', 36, 11.26], ['FreeChina', 14, 37.69]]
# 會(D)_能(D) 27.5 [['SCS', 16, 76.64], ['diary', 19, 12.28], ['228', 36, 11.26], ['FreeChina', 36, 18.06]]
# 要(D)_得(D) 27.5 [['SCS', 30, 44.41], ['FreeChina', 25, 26.69]]
# 可以(D)_要(D) 28.0 [['SCS', 27, 48.71], ['FreeChina', 29, 25.91]]
# 應該(D)_能(D) 29.0 [['SCS', 22, 58.02], ['FreeChina', 36, 18.06]]
# 要(D)_應(D) 29.5 [['SCS', 37, 37.25], ['diary', 27, 6.14], ['228', 20, 33.78], ['FreeChina', 32, 20.41]]
# 可(D)_要(D) 30 [['SCS', 30, 44.41], ['diary', 27, 6.14], ['FreeChina', 36, 18.06]]
# 必須(D)_可(D) 30.0 [['SCS', 42, 32.23], ['diary', 13, 18.42], ['228', 36, 11.26], ['FreeChina', 24, 27.48]]
# 須(D)_可(D) 31.0 [['SCS', 67, 17.19], ['diary', 19, 12.28], ['228', 15, 45.04], ['FreeChina', 43, 14.92]]
# 能(D)_得(D) 31 [['SCS', 67, 17.19], ['228', 11, 56.3], ['FreeChina', 31, 25.12]]
# 能(D)_可以(D) 32.5 [['SCS', 45, 28.65], ['diary', 13, 18.42], ['228', 36, 11.26], ['FreeChina', 29, 25.91]]
# 可(D)_可以(D) 33.0 [['SCS', 30, 44.41], ['diary', 27, 6.14], ['228', 36, 11.26], ['FreeChina', 61, 8.64]]
# 會(D)_可以(D) 34 [['SCS', 34, 40.83], ['diary', 9, 24.56], ['FreeChina', 73, 6.28]]
# 能(D)_應(D) 34.5 [['SCS', 33, 41.54], ['FreeChina', 36, 18.06]]
# 可以(D)_能(D) 35 [['SCS', 35, 38.68], ['228', 36, 11.26], ['FreeChina', 25, 26.69]]
# 必須(D)_能夠(D) 36 [['SCS', 55, 22.92], ['diary', 27, 6.14], ['FreeChina', 36, 18.06]]
# 能夠(D)_得(D) 36 [['228', 36, 11.26]]
# 當(D)_該(D) 36 [['228', 36, 11.26]]
# 可(D)_得(VJ) 37 [['SCS', 37, 37.25], ['228', 36, 11.26], ['FreeChina', 73, 6.28]]
# 應(D)_要(D) 37.0 [['SCS', 47, 25.79], ['diary', 27, 6.14], ['228', 11, 56.3], ['FreeChina', 95, 3.93]]
# 應(D)_得(VJ) 38.0 [['SCS', 61, 22.2], ['SCS', 203, 1.43], ['228', 15, 45.04], ['FreeChina', 9, 55.74]]
# 可以(D)_可(D) 39.0 [['SCS', 35, 38.68], ['FreeChina', 43, 14.92]]
# 要(D)_須(D) 42 [['SCS', 77, 13.61], ['diary', 19, 12.28], ['FreeChina', 42, 17.27]]
# 應(D)_該(D) 42.0 [['SCS', 104, 7.16], ['diary', 19, 12.28], ['228', 36, 11.26], ['FreeChina', 48, 13.35]]
# 需要(VK)_能(D) 43.0 [['SCS', 20, 63.75], ['FreeChina', 66, 7.85]]
# 應(D)_需要(VK) 43 [['SCS', 117, 5.73], ['228', 25, 22.52], ['FreeChina', 43, 14.92]]
# 可(D)_應(D) 43 [['SCS', 47, 25.79], ['diary', 27, 6.14], ['FreeChina', 43, 14.92]]
# 需(D)_可(D) 45.5 [['SCS', 55, 22.92], ['diary', 13, 18.42], ['228', 36, 11.26], ['FreeChina', 119, 2.36]]
# 要(D)_需要(VK) 45.5 [['SCS', 44, 29.37], ['FreeChina', 47, 14.13]]
# 可以(D)_需要(VK) 46.0 [['SCS', 39, 35.81], ['FreeChina', 53, 10.21]]
# 當(D)_可以(D) 48.0 [['diary', 27, 6.14], ['FreeChina', 69, 7.07]]
# 應該(D)_能夠(D) 48 [['SCS', 54, 23.64], ['228', 36, 11.26], ['FreeChina', 48, 13.35]]
# 可以(D)_得(D) 48 [['SCS', 117, 5.73], ['diary', 27, 6.14], ['FreeChina', 48, 13.35]]
# 能(D)_需要(VK) 49 [['SCS', 49, 25.07], ['228', 36, 11.26], ['FreeChina', 58, 9.42]]
# 會(D)_應該(D) 50 [['SCS', 50, 24.35], ['228', 36, 11.26], ['FreeChina', 82, 4.71]]
# 必須(D)_可以(D) 51 [['SCS', 63, 21.49], ['diary', 27, 6.14], ['FreeChina', 51, 12.56]]
# 可(D)_需要(VK) 51.0 [['SCS', 50, 24.35], ['FreeChina', 52, 10.99]]
# 應(D)_可以(D) 51.5 [['SCS', 50, 24.35], ['FreeChina', 53, 10.21]]
# 可以(D)_應該(D) 53 [['SCS', 82, 12.18], ['228', 36, 11.26], ['FreeChina', 53, 10.21]]
# 會(D)_應(D) 53 [['SCS', 99, 7.88], ['228', 7, 67.56], ['FreeChina', 53, 10.21]]
# 可以(D)_應(D) 53 [['SCS', 165, 2.87], ['diary', 27, 6.14], ['FreeChina', 53, 10.21]]
# 當(D)_應(D) 53.0 [['diary', 27, 6.14], ['FreeChina', 79, 5.5]]
# 會(D)_需要(VK) 55 [['SCS', 55, 22.92], ['228', 25, 22.52], ['FreeChina', 82, 4.71]]
# 會(D)_得(D) 58 [['SCS', 77, 13.61], ['228', 25, 22.52], ['FreeChina', 58, 9.42]]
# 要(D)_應該(D) 59.5 [['SCS', 46, 26.5], ['FreeChina', 73, 6.28]]
# 得(D)_可(D) 61 [['SCS', 94, 8.6], ['diary', 27, 6.14], ['FreeChina', 61, 8.64]]
# 要(D)_可以(VH) 61 [['SCS', 61, 22.2]]
# 能(D)_需(VK) 63 [['SCS', 63, 21.49], ['228', 36, 11.26], ['FreeChina', 79, 5.5]]
# 會(D)_該(D) 65 [['SCS', 65, 20.77], ['228', 36, 11.26], ['FreeChina', 160, 0.79]]
# 應該(D)_應該(D) 65 [['SCS', 65, 20.77], ['228', 25, 22.52], ['FreeChina', 95, 3.93]]
# 應(D)_得(D) 66 [['SCS', 136, 4.3], ['228', 36, 11.26], ['FreeChina', 66, 7.85]]
# 需要(VK)_可(D) 66.0 [['SCS', 50, 24.35], ['FreeChina', 82, 4.71]]
# 應該(D)_可(D) 66.5 [['SCS', 75, 14.33], ['FreeChina', 58, 9.42]]
# 可(D)_應該(D) 66.5 [['diary', 27, 6.14], ['FreeChina', 106, 3.14]]
# 要(D)_可(VH) 67 [['SCS', 67, 17.19]]
# 需要(VK)_可以(D) 68.5 [['SCS', 55, 22.92], ['FreeChina', 82, 4.71]]
# 得(D)_需要(VK) 69 [['SCS', 203, 1.43], ['228', 15, 45.04], ['FreeChina', 69, 7.07]]
# 能(D)_能夠(D) 70.5 [['SCS', 80, 12.89], ['FreeChina', 61, 8.64]]
# 得(D)_該(D) 73 [['FreeChina', 73, 6.28]]
# 必須(D)_得(D) 75.0 [['SCS', 84, 11.46], ['FreeChina', 66, 7.85]]
# 要(VC)_要(VC) 75 [['SCS', 75, 14.33]]
# 需(VK)_須(D) 75.0 [['228', 11, 56.3], ['FreeChina', 139, 1.57]]
# 能(D)_得(VJ) 75.5 [['SCS', 117, 5.73], ['FreeChina', 34, 18.84]]
# 須(D)_須(D) 76.5 [['SCS', 117, 5.73], ['diary', 27, 6.14], ['228', 36, 11.26], ['FreeChina', 119, 2.36]]
# 能(D)_必須(D) 77 [['SCS', 77, 13.61], ['228', 36, 11.26], ['FreeChina', 95, 3.93]]
# 可(D)_必須(D) 79 [['SCS', 92, 9.31], ['diary', 27, 6.14], ['FreeChina', 79, 5.5]]
# 需(D)_要(D) 79.5 [['SCS', 132, 5.01], ['diary', 27, 6.14]]
# 可以(D)_要(VC) 80 [['SCS', 80, 12.89]]
# 能夠(D)_能夠(D) 80.5 [['SCS', 55, 22.92], ['FreeChina', 106, 3.14]]
# 得(D)_得(D) 80.5 [['SCS', 55, 22.92], ['FreeChina', 106, 3.14]]
# 會(D)_須(D) 81.5 [['SCS', 136, 4.3], ['diary', 27, 6.14]]
# 當(D)_須(D) 82.0 [['228', 25, 22.52], ['FreeChina', 139, 1.57]]
# 須(D)_得(D) 82 [['SCS', 203, 1.43], ['228', 25, 22.52], ['FreeChina', 82, 4.71]]
# 必須(D)_需要(VK) 82 [['FreeChina', 82, 4.71]]
# 須(D)_應(D) 82 [['SCS', 165, 2.87], ['228', 36, 11.26], ['FreeChina', 82, 4.71]]
# 可(D)_該(D) 82 [['SCS', 117, 5.73], ['228', 25, 22.52], ['FreeChina', 82, 4.71]]
# 能夠(D)_能(D) 82 [['SCS', 84, 11.46], ['diary', 27, 6.14], ['FreeChina', 82, 4.71]]
# 須(D)_要(D) 83.0 [['diary', 27, 6.14], ['FreeChina', 139, 1.57]]
# 可以(D)_必須(D) 83.5 [['SCS', 94, 8.6], ['FreeChina', 73, 6.28]]
# 會(D)_需(VK) 84 [['SCS', 84, 11.46]]
# 必須(D)_必須(D) 84.0 [['SCS', 99, 7.88], ['FreeChina', 69, 7.07]]
# 需要(VK)_需要(VK) 84 [['SCS', 84, 11.46]]
# 可(D)_需(VK) 86.5 [['SCS', 67, 17.19], ['FreeChina', 106, 3.14]]
# 會(D)_必須(D) 88.5 [['SCS', 82, 12.18], ['FreeChina', 95, 3.93]]
# 可以(D)_得(VJ) 89.0 [['SCS', 117, 5.73], ['FreeChina', 61, 8.64]]
# 會(D)_得(VJ) 90 [['SCS', 90, 10.03], ['SCS', 203, 1.43], ['FreeChina', 73, 6.28]]
# 需(D)_可(VH) 90 [['SCS', 90, 10.03]]
# 要(D)_當(VG) 91.0 [['SCS', 43, 30.08], ['FreeChina', 139, 1.57]]
# 需(D)_能(D) 92.0 [['SCS', 24, 54.44], ['FreeChina', 160, 0.79]]
# 可以(D)_需(VK) 93.0 [['SCS', 67, 17.19], ['FreeChina', 119, 2.36]]
# 要(D)_該(D) 94 [['SCS', 94, 8.6], ['diary', 27, 6.14], ['FreeChina', 139, 1.57]]
# 應(D)_必須(D) 95 [['SCS', 203, 1.43], ['228', 36, 11.26], ['FreeChina', 95, 3.93]]
# 可以(D)_能夠(D) 95.0 [['SCS', 84, 11.46], ['FreeChina', 106, 3.14]]
# 能(D)_當(VG) 99.5 [['SCS', 104, 7.16], ['FreeChina', 95, 3.93]]
# 需(VK)_能(D) 104 [['SCS', 104, 7.16]]
# 要(D)_能(VL) 104 [['SCS', 104, 7.16]]
# 需(D)_需(D) 104 [['SCS', 104, 7.16]]
# 會(D)_要(VC) 104 [['SCS', 104, 7.16]]
# 須(VK)_能(D) 104 [['SCS', 104, 7.16]]
# 能夠(D)_可以(D) 105.0 [['SCS', 104, 7.16], ['FreeChina', 106, 3.14]]
# 會(D)_能夠(D) 105.0 [['SCS', 104, 7.16], ['FreeChina', 106, 3.14]]
# 能(D)_應該(D) 106 [['SCS', 117, 5.73], ['228', 36, 11.26], ['FreeChina', 106, 3.14]]
# 要(D)_應當(D) 106 [['FreeChina', 106, 3.14]]
# 可以(D)_該(D) 109.0 [['SCS', 99, 7.88], ['FreeChina', 119, 2.36]]
# 須(D)_應該(D) 109.0 [['SCS', 203, 1.43], ['228', 15, 45.04]]
# 應當(D)_能(D) 109.0 [['SCS', 136, 4.3], ['FreeChina', 82, 4.71]]
# 應該(D)_需要(VK) 111.5 [['SCS', 117, 5.73], ['FreeChina', 106, 3.14]]
# 應當(D)_可以(D) 114.0 [['SCS', 159, 3.58], ['FreeChina', 69, 7.07]]
# 應(D)_需(D) 114.0 [['SCS', 89, 10.74], ['FreeChina', 139, 1.57]]
# 會(VL)_要(D) 115 [['SCS', 115, 6.45]]
# 應(D)_需(VK) 115.5 [['SCS', 136, 4.3], ['FreeChina', 95, 3.93]]
# 可(D)_需(D) 116.5 [['SCS', 73, 15.76], ['FreeChina', 160, 0.79]]
# 能(D)_該(D) 116.5 [['SCS', 73, 15.76], ['FreeChina', 160, 0.79]]
# 要(D)_需(D) 116.5 [['SCS', 94, 8.6], ['FreeChina', 139, 1.57]]
# 得(VJ)_得(VJ) 117 [['SCS', 117, 5.73]]
# 需(VK)_必須(D) 117 [['SCS', 117, 5.73]]
# 能夠(D)_要(D) 117 [['SCS', 117, 5.73]]
# 能(D)_需(D) 118.0 [['SCS', 117, 5.73], ['FreeChina', 119, 2.36]]
# 必須(D)_應(D) 119 [['SCS', 136, 4.3], ['diary', 27, 6.14], ['FreeChina', 119, 2.36]]
# 可(D)_應當(D) 119 [['FreeChina', 119, 2.36]]
# 能夠(D)_應該(D) 119.0 [['SCS', 99, 7.88], ['FreeChina', 139, 1.57]]
# 得(D)_須(D) 119 [['FreeChina', 119, 2.36]]
# 可以(D)_應當(D) 119 [['FreeChina', 119, 2.36]]
# 應該(D)_應(D) 119 [['SCS', 165, 2.87], ['diary', 27, 6.14], ['FreeChina', 119, 2.36]]
# 應當(D)_可(D) 119 [['FreeChina', 119, 2.36]]
# 須(D)_能夠(D) 119 [['FreeChina', 119, 2.36]]
# 可(D)_當(D) 119.5 [['SCS', 203, 1.43], ['228', 36, 11.26]]
# 可(D)_能夠(D) 121.0 [['SCS', 136, 4.3], ['FreeChina', 106, 3.14]]
# 應該(D)_該(D) 121.0 [['SCS', 136, 4.3], ['FreeChina', 106, 3.14]]
# 當(D)_要(D) 123.5 [['SCS', 165, 2.87], ['FreeChina', 82, 4.71]]
# 得(D)_應(D) 123.5 [['SCS', 165, 2.87], ['FreeChina', 82, 4.71]]
# 應該(D)_必須(D) 126.0 [['SCS', 92, 9.31], ['FreeChina', 160, 0.79]]
# 需要(VK)_要(D) 127.0 [['SCS', 94, 8.6], ['FreeChina', 160, 0.79]]
# 需要(VK)_能夠(D) 127.0 [['SCS', 115, 6.45], ['FreeChina', 139, 1.57]]
# 應當(D)_要(D) 127.5 [['SCS', 136, 4.3], ['FreeChina', 119, 2.36]]
# 能夠(D)_可(D) 130.0 [['SCS', 165, 2.87], ['FreeChina', 95, 3.93]]
# 可(D)_當(VG) 132.0 [['SCS', 104, 7.16], ['FreeChina', 160, 0.79]]
# 能(D)_要(VC) 132.0 [['SCS', 104, 7.16], ['FreeChina', 160, 0.79]]
# 必須(D)_該(D) 132 [['SCS', 132, 5.01]]
# 要(VE)_能(D) 132 [['SCS', 132, 5.01]]
# 須(VK)_可(D) 136 [['SCS', 136, 4.3]]
# 需要(VK)_需(VK) 136 [['SCS', 136, 4.3]]
# 應該(D)_可以(VH) 136 [['SCS', 136, 4.3]]
# 需(VK)_可(D) 136 [['SCS', 136, 4.3], ['228', 36, 11.26], ['FreeChina', 160, 0.79]]
# 要(D)_須(VK) 136 [['SCS', 136, 4.3]]
# 需(D)_須(VK) 136 [['SCS', 136, 4.3]]
# 會(D)_要(VE) 136 [['SCS', 136, 4.3]]
# 需(D)_需(VK) 136 [['SCS', 136, 4.3]]
# 得(D)_可(VH) 136 [['SCS', 136, 4.3]]
# 當(VG)_當(VG) 136 [['SCS', 136, 4.3]]
# 可以(VH)_可以(VH) 136 [['SCS', 136, 4.3]]
# 需要(VK)_應(D) 137.5 [['SCS', 136, 4.3], ['FreeChina', 139, 1.57]]
# 當(VG)_能(D) 138.5 [['SCS', 117, 5.73], ['FreeChina', 160, 0.79]]
# 需(D)_應(D) 138.5 [['SCS', 117, 5.73], ['FreeChina', 160, 0.79]]
# 可(D)_要(VC) 138.5 [['SCS', 117, 5.73], ['FreeChina', 160, 0.79]]
# 必須(D)_應該(D) 139.0 [['SCS', 159, 3.58], ['FreeChina', 119, 2.36]]
# 應當(D)_必須(D) 139 [['FreeChina', 139, 1.57]]
# 能(D)_當(D) 139 [['FreeChina', 139, 1.57]]
# 得(D)_應該(D) 139 [['FreeChina', 139, 1.57]]
# 須(D)_需要(VK) 139 [['FreeChina', 139, 1.57]]
# 要(D)_得(VJ) 142.0 [['SCS', 165, 2.87], ['FreeChina', 119, 2.36]]
# 需(D)_得(D) 142.0 [['SCS', 165, 2.87], ['FreeChina', 119, 2.36]]
# 需要(VK)_必須(D) 142.0 [['SCS', 165, 2.87], ['FreeChina', 119, 2.36]]
# 能夠(D)_得(VJ) 142.5 [['SCS', 203, 1.43], ['FreeChina', 82, 4.71]]
# 要(VC)_要(D) 146.0 [['SCS', 132, 5.01], ['FreeChina', 160, 0.79]]
# 能夠(D)_需要(VK) 146.5 [['SCS', 198, 2.15], ['FreeChina', 95, 3.93]]
# 要(D)_要(VC) 148.0 [['SCS', 136, 4.3], ['FreeChina', 160, 0.79]]
# 應(D)_能夠(D) 148.0 [['SCS', 136, 4.3], ['FreeChina', 160, 0.79]]
# 必須(D)_需(D) 148.0 [['SCS', 136, 4.3], ['FreeChina', 160, 0.79]]
# 應(D)_應該(D) 149.0 [['SCS', 203, 1.43], ['FreeChina', 95, 3.93]]
# 需(VK)_要(D) 149.0 [['SCS', 159, 3.58], ['FreeChina', 139, 1.57]]
# 須(D)_可以(D) 149.0 [['SCS', 203, 1.43], ['FreeChina', 95, 3.93]]
# 必須(D)_須(D) 149.0 [['SCS', 159, 3.58], ['FreeChina', 139, 1.57]]
# 要(D)_需(VK) 151.0 [['SCS', 99, 7.88], ['SCS', 203, 1.43]]
# 得(D)_要(VC) 152.0 [['SCS', 165, 2.87], ['FreeChina', 139, 1.57]]
# 可以(D)_當(VG) 152.0 [['SCS', 165, 2.87], ['FreeChina', 139, 1.57]]
# 能(D)_須(D) 154.5 [['SCS', 203, 1.43], ['FreeChina', 106, 3.14]]
# 能夠(D)_必須(D) 159 [['SCS', 159, 3.58]]
# 須(D)_該(D) 159 [['SCS', 159, 3.58], ['228', 36, 11.26], ['FreeChina', 160, 0.79]]
# 當(D)_得(VJ) 160 [['FreeChina', 160, 0.79]]
# 應該(D)_得(D) 160 [['FreeChina', 160, 0.79]]
# 當(VG)_需(VK) 160 [['FreeChina', 160, 0.79]]
# 可以(VH)_必須(D) 160 [['FreeChina', 160, 0.79]]
# 會(D)_需(D) 160 [['FreeChina', 160, 0.79]]
# 需要(VK)_當(D) 160 [['FreeChina', 160, 0.79]]
# 要(D)_應該(VH) 160 [['FreeChina', 160, 0.79]]
# 當(VG)_必須(D) 160 [['FreeChina', 160, 0.79]]
# 應當(D)_應當(D) 160 [['FreeChina', 160, 0.79]]
# 應當(D)_得(D) 160 [['FreeChina', 160, 0.79]]
# 應當(D)_當(VG) 160 [['FreeChina', 160, 0.79]]
# 得(VJ)_可(D) 160 [['FreeChina', 160, 0.79]]
# 當(D)_得(D) 160 [['FreeChina', 160, 0.79]]
# 應當(D)_需(VK) 160 [['FreeChina', 160, 0.79]]
# 得(VJ)_需(VK) 160 [['FreeChina', 160, 0.79]]
# 得(D)_能夠(D) 160 [['FreeChina', 160, 0.79]]
# 得(D)_需(D) 160 [['FreeChina', 160, 0.79]]
# 應當(D)_能夠(D) 160 [['FreeChina', 160, 0.79]]
# 當(VG)_應該(D) 160 [['FreeChina', 160, 0.79]]
# 需(D)_必須(D) 160 [['FreeChina', 160, 0.79]]
# 要(VC)_必須(D) 160 [['FreeChina', 160, 0.79]]
# 得(D)_可以(D) 161.0 [['SCS', 203, 1.43], ['FreeChina', 119, 2.36]]
# 可以(D)_須(D) 161.0 [['SCS', 203, 1.43], ['FreeChina', 119, 2.36]]
# 可以(D)_需(D) 161.0 [['SCS', 203, 1.43], ['FreeChina', 119, 2.36]]
# 可以(D)_當(D) 162.5 [['SCS', 165, 2.87], ['FreeChina', 160, 0.79]]
# 能夠(D)_應(D) 162.5 [['SCS', 165, 2.87], ['FreeChina', 160, 0.79]]
# 能(D)_可以(VH) 162.5 [['SCS', 165, 2.87], ['FreeChina', 160, 0.79]]
# 必須(D)_當(VG) 162.5 [['SCS', 165, 2.87], ['FreeChina', 160, 0.79]]
# 得(D)_必須(D) 162.5 [['SCS', 165, 2.87], ['FreeChina', 160, 0.79]]
# 需(D)_可以(D) 162.5 [['SCS', 165, 2.87], ['FreeChina', 160, 0.79]]
# 須(D)_可(VH) 165 [['SCS', 165, 2.87]]
# 當(VC)_要(D) 165 [['SCS', 165, 2.87]]
# 當(VG)_要(D) 165 [['SCS', 165, 2.87]]
# 可(VH)_可以(VH) 165 [['SCS', 165, 2.87]]
# 需要(VK)_得(VJ) 165 [['SCS', 165, 2.87]]
# 需(D)_能夠(D) 165 [['SCS', 165, 2.87]]
# 需(D)_需要(VK) 165 [['SCS', 165, 2.87]]
# 要(VE)_要(VE) 165 [['SCS', 165, 2.87]]
# 可以(D)_可(VH) 165 [['SCS', 165, 2.87]]
# 可以(D)_當(VC) 165 [['SCS', 165, 2.87]]
# 能(VL)_可(D) 165 [['SCS', 165, 2.87]]
# 可(D)_可(VH) 165 [['SCS', 165, 2.87]]
# 會(D)_當(VC) 165.0 [['SCS', 165, 2.87], ['SCS', 165, 2.87]]
# 會(D)_須(VK) 165 [['SCS', 165, 2.87]]
# 能(D)_可(VH) 165 [['SCS', 165, 2.87]]
# 可(D)_須(D) 171.0 [['SCS', 203, 1.43], ['FreeChina', 139, 1.57]]
# 必須(D)_需(VK) 171.0 [['SCS', 203, 1.43], ['FreeChina', 139, 1.57]]
# 需要(VK)_得(D) 171.0 [['SCS', 203, 1.43], ['FreeChina', 139, 1.57]]
# 得(D)_得(VJ) 179.0 [['SCS', 198, 2.15], ['FreeChina', 160, 0.79]]
# 須(D)_需(VK) 179.0 [['SCS', 198, 2.15], ['FreeChina', 160, 0.79]]
# 會(D)_當(VG) 181.5 [['SCS', 203, 1.43], ['FreeChina', 160, 0.79]]
# 得(VJ)_應(D) 181.5 [['SCS', 203, 1.43], ['FreeChina', 160, 0.79]]
# 要(VC)_可(D) 181.5 [['SCS', 203, 1.43], ['FreeChina', 160, 0.79]]
# 必須(D)_應當(D) 181.5 [['SCS', 203, 1.43], ['FreeChina', 160, 0.79]]
# 能夠(D)_需(VK) 181.5 [['SCS', 203, 1.43], ['FreeChina', 160, 0.79]]
# 應該(D)_得(VJ) 181.5 [['SCS', 203, 1.43], ['FreeChina', 160, 0.79]]
# 須(D)_必須(D) 181.5 [['SCS', 203, 1.43], ['FreeChina', 160, 0.79]]
# 應該(D)_需(VK) 181.5 [['SCS', 203, 1.43], ['FreeChina', 160, 0.79]]
# 得(VJ)_能(D) 181.5 [['SCS', 203, 1.43], ['FreeChina', 160, 0.79]]
# 必須(D)_得(VJ) 181.5 [['SCS', 203, 1.43], ['FreeChina', 160, 0.79]]
# 應(D)_應當(D) 181.5 [['SCS', 203, 1.43], ['FreeChina', 160, 0.79]]
# 需(D)_得(VJ) 198 [['SCS', 198, 2.15]]
# 必須(D)_要(VC) 198 [['SCS', 198, 2.15]]
# 會(D)_可以(VH) 203 [['SCS', 203, 1.43]]
# 應該(D)_需(D) 203 [['SCS', 203, 1.43]]
# 會(VC)_得(VJ) 203 [['SCS', 203, 1.43]]
# 要(VC)_應該(D) 203 [['SCS', 203, 1.43]]
# 可(D)_能(VL) 203 [['SCS', 203, 1.43]]
# 能(VL)_得(D) 203 [['SCS', 203, 1.43]]
# 需要(VK)_應該(D) 203 [['SCS', 203, 1.43]]
# 要(VC)_應(D) 203 [['SCS', 203, 1.43]]
# 需要(VK)_須(D) 203 [['SCS', 203, 1.43]]
# 會(D)_當(VH) 203 [['SCS', 203, 1.43]]
# 要(VC)_能(D) 203 [['SCS', 203, 1.43]]
# 得(VJ)_該(D) 203 [['SCS', 203, 1.43]]
# 會(D)_得(VC) 203 [['SCS', 203, 1.43]]
# 能(D)_能(VL) 203 [['SCS', 203, 1.43]]
# 能(VL)_能(D) 203 [['SCS', 203, 1.43]]
# 應當(D)_應(D) 203 [['SCS', 203, 1.43]]
# 需(VK)_需(VK) 203 [['SCS', 203, 1.43]]
# 能(VL)_能(VL) 203 [['SCS', 203, 1.43]]
# 會(D)_得(VH) 203 [['SCS', 203, 1.43]]
# 應該(D)_當(D) 203 [['SCS', 203, 1.43]]
# 可(D)_要(VE) 203 [['SCS', 203, 1.43]]
# 當(VG)_需要(VK) 203 [['SCS', 203, 1.43]]
# 需(D)_須(D) 203 [['SCS', 203, 1.43]]
# 需(VK)_能夠(D) 203 [['SCS', 203, 1.43]]
# 得(VJ)_必須(D) 203 [['SCS', 203, 1.43]]
# 當(VG)_可以(D) 203 [['SCS', 203, 1.43]]
# 需(VK)_可(VH) 203 [['SCS', 203, 1.43]]
# 要(VC)_可以(D) 203 [['SCS', 203, 1.43]]
# 應(D)_當(D) 203 [['SCS', 203, 1.43]]
# 可(D)_得(VC) 203 [['SCS', 203, 1.43]]
# 應該(D)_當(VG) 203 [['SCS', 203, 1.43]]
# 得(VJ)_要(D) 203 [['SCS', 203, 1.43]]
# 要(D)_當(VC) 203 [['SCS', 203, 1.43]]
# 必須(D)_可以(VH) 203 [['SCS', 203, 1.43]]
# 應(VE)_得(D) 203 [['SCS', 203, 1.43]]
# 當(VG)_得(D) 203 [['SCS', 203, 1.43]]
# 能夠(D)_當(VG) 203 [['SCS', 203, 1.43]]
# 當(VG)_可(D) 203 [['SCS', 203, 1.43]]
# 需(VK)_得(D) 203 [['SCS', 203, 1.43]]
# 可(D)_須(VK) 203 [['SCS', 203, 1.43]]
# 得(VH)_得(VH) 203 [['SCS', 203, 1.43]]
# 可以(D)_須(VK) 203 [['SCS', 203, 1.43]]
# 會(VC)_應(D) 203 [['SCS', 203, 1.43]]
# 得(D)_能(VL) 203 [['SCS', 203, 1.43]]
# 必須(D)_可(VH) 203 [['SCS', 203, 1.43]]
# 需要(VK)_該(D) 203 [['SCS', 203, 1.43]]
# 須(D)_需(D) 203 [['SCS', 203, 1.43]]
# 必須(D)_要(VE) 203 [['SCS', 203, 1.43]]
# 要(VE)_可以(D) 203 [['SCS', 203, 1.43]]
# 應(D)_可以(VH) 203 [['SCS', 203, 1.43]]
# 需要(VK)_要(VC) 203 [['SCS', 203, 1.43]]
# 須(VK)_須(VK) 203 [['SCS', 203, 1.43]]
# 會(VL)_可以(D) 203 [['SCS', 203, 1.43]]
# 需(D)_能(VL) 203 [['SCS', 203, 1.43]]
# 須(VK)_可(VH) 203 [['SCS', 203, 1.43]]
# 會(D)_能(VL) 203 [['SCS', 203, 1.43]]
# 得(D)_可以(VH) 203 [['SCS', 203, 1.43]]
# 需要(VK)_應當(D) 203 [['SCS', 203, 1.43]]
# 會(D)_必須(VH) 203 [['SCS', 203, 1.43]]
# 能夠(D)_該(D) 203 [['SCS', 203, 1.43]]
# 應該(D)_應當(D) 203 [['SCS', 203, 1.43]]
# 可(VH)_可以(D) 203 [['SCS', 203, 1.43]]
# 需(VK)_需要(VK) 203 [['SCS', 203, 1.43]]
# 能(D)_當(VC) 203 [['SCS', 203, 1.43]]
# 會(VL)_能(D) 203 [['SCS', 203, 1.43]]
# 需要(VK)_可(VH) 203 [['SCS', 203, 1.43]]
# END
